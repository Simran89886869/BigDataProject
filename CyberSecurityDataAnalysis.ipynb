# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# Set visualization style
sns.set(style="whitegrid")

# Load the data with the correct filename
df = pd.read_csv('Global_Cybersecurity_Threats_2015-2024.csv')

# Display basic information
print(f"Dataset shape: {df.shape}")
print("\nFirst 5 rows:")
display(df.head())
# Out:
# Dataset shape: (3000, 10)
#
# First 5 rows:
#    Country  Year        Attack Type     Target Industry  \
# 0    China  2019           Phishing           Education
# 1    China  2019         Ransomware              Retail
# 2    India  2017  Man-in-the-Middle                  IT
# 3       UK  2024         Ransomware  Telecommunications
# 4  Germany  2018  Man-in-the-Middle                  IT
#
#    Financial Loss (in Million $)  Number of Affected Users Attack Source  \
# 0                          80.53                    773169  Hacker Group
# 1                          62.19                    295961  Hacker Group
# 2                          38.65                    605895  Hacker Group
# 3                          41.44                    659320  Nation-state
# 4                          74.41                    810682       Insider
#
#   Security Vulnerability Type Defense Mechanism Used  \
# 0          Unpatched Software                    VPN
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is already loaded correctly
# Ensure column names are correct by checking them first
print(df.columns)

# Rename columns to avoid any case sensitivity or space issues
df.columns = df.columns.str.strip()

# Use the correct column name (from your image, it should be "Year")
df_by_year = df.groupby('Year').size()

# Plot the trend of cybersecurity threats over time
plt.figure(figsize=(14, 8))
sns.lineplot(x=df_by_year.index, y=df_by_year.values, marker="o", linestyle="-")

plt.title('Trend of Cybersecurity Threats (2015-2024)')
plt.xlabel('Year')
plt.ylabel('Number of Threats')
plt.grid(True)
plt.show()
# Out:
# Index(['Country', 'Year', 'Attack Type', 'Target Industry',
#        'Financial Loss (in Million $)', 'Number of Affected Users',
#        'Attack Source', 'Security Vulnerability Type',
#        'Defense Mechanism Used', 'Incident Resolution Time (in Hours)'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print(df.columns)

df.columns = df.columns.str.strip()

threat_counts = df['Attack Type'].value_counts()

plt.figure(figsize=(12, 6))
sns.barplot(x=threat_counts.index, y=threat_counts.values, palette="viridis")

plt.title('Distribution of Cybersecurity Threat Types')
plt.xlabel('Threat Type')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# Index(['Country', 'Year', 'Attack Type', 'Target Industry',
#        'Financial Loss (in Million $)', 'Number of Affected Users',
#        'Attack Source', 'Security Vulnerability Type',
#        'Defense Mechanism Used', 'Incident Resolution Time (in Hours)'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df.columns = df.columns.str.strip()

df_by_year = df.groupby('Year').size()

plt.figure(figsize=(14, 8))
sns.lineplot(x=df_by_year.index, y=df_by_year.values, marker="o", linestyle="-")

plt.title('Trend of Cybersecurity Threats (2015-2024)')
plt.xlabel('Year')
plt.ylabel('Number of Threats')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df.columns = df.columns.str.strip()

country_counts = df['Country'].value_counts().head(20)

plt.figure(figsize=(16, 10))
sns.barplot(x=country_counts.values, y=country_counts.index, palette="magma")

# Horizontal bar chart showing the top 20 countries by number of cybersecurity threats
plt.title('Top 20 Countries by Number of Cybersecurity Threats')
plt.xlabel('Number of Threats')
plt.ylabel('Country')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df.columns = df.columns.str.strip()

numeric_df = df.select_dtypes(include=[np.number])

plt.figure(figsize=(12, 10))

# Heatmap showing the correlation between numeric features
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm', linewidths=0.5)

plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Feature importance
plt.figure(figsize=(12, 8))
feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': model.feature_importances_
}).sort_values('Importance', ascending=False)

sns.barplot(x='Importance', y='Feature', data=feature_importance.head(20))
plt.title('Top 20 Feature Importance')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 8
#       5 # Feature importance
#       6 plt.figure(figsize=(12, 8))
#       7 feature_importance = pd.DataFrame({
# ----> 8     'Feature': X.columns,
#       9     'Importance': model.feature_importances_
#      10 }).sort_values('Importance', ascending=False)
#      12 sns.barplot(x='Importance', y='Feature', data=feature_importance.head(20))
#      13 plt.title('Top 20 Feature Importance')
#
# NameError: name 'X' is not defined

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

if 'severity' in df_clean.columns:  
    X = df_clean.drop('severity', axis=1)
    y = df_clean['severity']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    model = RandomForestClassifier(n_estimators=100, random_state=42)
    model.fit(X_train_scaled, y_train)

    # Make predictions
    y_pred = model.predict(X_test_scaled)

    # Print evaluation metrics
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print("\nClassification Report:\n", classification_report(y_test, y_pred))
    print("\nConfusion Matrix:\n", confusion_matrix(y_test, y_pred))

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(x='Year', y='Number of Affected Users', data=df, marker='o', color='b')
plt.title('Trend of Affected Users Over Years')
plt.xlabel('Year')
plt.ylabel('Number of Affected Users')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(12, 6))
top_countries = df.groupby('Country')['Number of Affected Users'].sum().sort_values(ascending=False).head(10)
sns.barplot(x=top_countries.index, y=top_countries.values, palette='coolwarm')
plt.title('Top 10 Countries Affected by Cyber Attacks')
plt.xlabel('Country')
plt.ylabel('Number of Affected Users')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x='Attack Type', y='Financial Loss (in Million $)', data=df, palette='magma')
plt.title('Financial Loss by Attack Type')
plt.xlabel('Attack Type')
plt.ylabel('Financial Loss (Million $)')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(y='Defense Mechanism Used', data=df, palette='viridis', order=df['Defense Mechanism Used'].value_counts().index)
plt.title('Frequency of Defense Mechanisms Used')
plt.xlabel('Count')
plt.ylabel('Defense Mechanism')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

fig, axes = plt.subplots(3, 2, figsize=(18, 15))
fig.suptitle('Global Cybersecurity Threats Analysis (2015-2024)', fontsize=16)

sns.lineplot(ax=axes[0, 0], x='Year', y='Number of Affected Users', data=df, marker='o', color='b')
axes[0, 0].set_title('Trend of Affected Users Over Years')

top_countries = df.groupby('Country')['Number of Affected Users'].sum().sort_values(ascending=False).head(10)
sns.barplot(ax=axes[0, 1], x=top_countries.index, y=top_countries.values, palette='coolwarm'xes[0, 1].set_title('Top 10 Countries Affected')
axes[0, 1].set_xticklabels(top_countries.index, rotation=45)

sns.barplot(ax=axes[1, 0], x='Attack Type', y='Financial Loss (in Million $)', data=df, palette='magma')
axes[1, 0].set_title('Financial Loss by Attack Type')
axes[1, 0].set_xticklabels(df['Attack Type'].unique(), rotation=45)

vuln_counts = df['Security Vulnerability Type'].value_counts()
axes[1, 1].pie(vuln_counts, labels=vuln_counts.index, autopct='%1.1f%%', colors=sns.color_palette("pastel"))
axes[1, 1].set_title('Distribution of Security Vulnerabilities')
sns.countplot(ax=axes[2, 0], y='Defense Mechanism Used', data=df, palette='viridis', order=df['Defense Mechanism Used'].value_counts().index)
axes[2, 0].set_title('Most Used Defense Mechanisms')

axes[2, 1].axis('off')

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
